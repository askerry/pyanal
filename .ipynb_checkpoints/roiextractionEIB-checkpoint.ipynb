# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
import roiextraction_funcs as ref
import seaborn as sns
from mypymvpa.utilities.misc import makeIDs

# %%
#set exp details
rootdir='/mindhive/saxelab2/'
studyname='EIB'
studydir=rootdir+studyname+'/'
roidir='ROI_EIB1'
taskname='EIB_main'
conditions=['nh', 'nu','sh','su', 'mh','mu','fh','fu']
ASDsubjnums=[28,29,30,31,32,33,34,36,57]
NTsubjnums=[11,16,18,21,22,25,26,27,38,39,40,41,42,17,23]
expandedNTs=[10, 11, 12, 13, 15, 16, 17, 18, 19, 20, 21, 22, 23, 25, 26,27,38,39,40,41,42]
subjlist=makeIDs('EIB',expandedNTs)

# %%
#assign colors
colors=sns.color_palette("husl", 16)
colors=[colors[el] for el in [0,1,2,3,8,9,10,11]]

# %%
#specify sets of conditions to combine and compare
facedict={'faceh':{'conds':['mh','fh'], 'color':'pink'}, 'faceu':{'conds':['mu','fu'], 'color':'green'}}
situationdict={'situationh':{'conds':['sh','nh'], 'color':'red'}, 'situationu':{'conds':['su','nu'], 'color':'brown'}}
comparisons=[facedict,situationdict]

# %%
pscfiles,betafiles=ref.findextractedfiles(studydir,roidir,taskname)

# %%
ref.analyzepsc(pscfiles,conditions,colors,subjlist)
# Out:
# /mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['Arial'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
roilist=ref.analyzebetas(betafiles,conditions,colors,subjlist)

# %%
ref.compareconds(studydir,roidir,taskname,roilist,comparisons,subjlist)
# Out:
# DMPFC_tomloc_with_art_reg_results_normed_con01 :faceu-faceh: t(20)=1.953, p=0.065.
# LSTS_tomloc_with_art_reg_results_normed_con01 :faceu-faceh: t(20)=-1.110, p=0.280.
# LTPJ_tomloc_with_art_reg_results_normed_con01 :faceu-faceh: t(20)=-0.361, p=0.722.
# MMPFC_tomloc_with_art_reg_results_normed_con01 :faceu-faceh: t(20)=-0.822, p=0.421.
# PC_tomloc_with_art_reg_results_normed_con01 :faceu-faceh: t(20)=-0.298, p=0.769.
# ROI_lFFA_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :faceu-faceh: t(16)=-1.662, p=0.116.
# ROI_lOFA_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :faceu-faceh: t(9)=-2.198, p=0.056.
# ROI_lSTS_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :faceu-faceh: t(16)=-0.877, p=0.393.
# ROI_rFFA_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :faceu-faceh: t(17)=-1.469, p=0.160.
# ROI_rOFA_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :faceu-faceh: t(17)=-2.897, p=0.010.
# ROI_rpSTS_BDbiomot_EmoBioLoc_with_art_reg_results_normed_con10 :faceu-faceh: t(18)=-0.923, p=0.368.
# ROI_rSTS_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :faceu-faceh: t(17)=-1.391, p=0.182.
# RSTS_tomloc_with_art_reg_results_normed_con01 :faceu-faceh: t(20)=0.649, p=0.524.
# RTPJ_tomloc_with_art_reg_results_normed_con01 :faceu-faceh: t(20)=0.135, p=0.894.
# VMPFC_tomloc_with_art_reg_results_normed_con01 :faceu-faceh: t(20)=-2.723, p=0.013.
# DMPFC_tomloc_with_art_reg_results_normed_con01 :situationh-situationu: t(20)=-1.452, p=0.162.
# LSTS_tomloc_with_art_reg_results_normed_con01 :situationh-situationu: t(20)=-0.632, p=0.535.
# LTPJ_tomloc_with_art_reg_results_normed_con01 :situationh-situationu: t(20)=-1.200, p=0.244.
# MMPFC_tomloc_with_art_reg_results_normed_con01 :situationh-situationu: t(20)=-0.591, p=0.561.
# PC_tomloc_with_art_reg_results_normed_con01 :situationh-situationu: t(20)=-0.629, p=0.537.
# ROI_lFFA_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :situationh-situationu: t(16)=-0.991, p=0.336.
# ROI_lOFA_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :situationh-situationu: t(9)=0.948, p=0.368.
# ROI_lSTS_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :situationh-situationu: t(16)=-0.556, p=0.586.
# ROI_rFFA_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :situationh-situationu: t(17)=0.801, p=0.434.
# ROI_rOFA_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :situationh-situationu: t(17)=0.501, p=0.623.
# ROI_rpSTS_BDbiomot_EmoBioLoc_with_art_reg_results_normed_con10 :situationh-situationu: t(18)=-2.537, p=0.021.
# ROI_rSTS_kanparcel_EmoBioLoc_with_art_reg_results_normed_con08 :situationh-situationu: t(17)=-3.859, p=0.001.
# RSTS_tomloc_with_art_reg_results_normed_con01 :situationh-situationu: t(20)=-1.265, p=0.220.
# RTPJ_tomloc_with_art_reg_results_normed_con01 :situationh-situationu: t(20)=-2.243, p=0.036.
# VMPFC_tomloc_with_art_reg_results_normed_con01 :situationh-situationu: t(20)=1.424, p=0.170.

# %%
groupa={'subjects':makeIDs(studyname,ASDsubjnums),'groupname':'ASD'}
groupb={'subjects':makeIDs(studyname,NTsubjnums),'groupname':'NT'}
ref.comparegroupbetas(studydir,roidir,taskname,roilist,comparisons,[groupa,groupb])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-14-bc9a22645edd> in <module>()
#       1 groupa={'subjects':makeIDs(studyname,ASDsubjnums),'groupname':'ASD'}
#       2 groupb={'subjects':makeIDs(studyname,NTsubjnums),'groupname':'NT'}
# ----> 3 ref.comparegroupbetas(studydir,roidir,taskname,roilist,comparisons,[groupa,groupb])
#
# /mindhive/saxelab/scripts/aesscripts/pyanal/roiextraction_funcs.pyc in comparegroupbetas(studydir, roidir, taskname, roilist, comparisons, groups)
#     209                 dataindex=colnames.index('mean')
#     210                 data=[row for row in reader]
# --> 211             mushconditions2compare_groups(roi,comp, data, dataindex, subjindex, roiindex, condindex, groups)
#     212
#
# /mindhive/saxelab/scripts/aesscripts/pyanal/roiextraction_funcs.pyc in mushconditions2compare_groups(roi, conditiondict, data, dataindex, subjindex, roiindex, condindex, groups)
#     170         clusteredmeans=[(np.mean(groupmushes[group1n][0]),np.mean(groupmushes[group1n][1])),(np.mean(groupmushes[group2n][0]),np.mean(groupmushes[group2n][1]))]
#     171         clusteredsems=[(np.std(groupmushes[group1n][0], ddof=1)/np.sqrt(len(groupmushes[group1n][0])),np.std(groupmushes[group1n][1], ddof=1)/np.sqrt(len(groupmushes[group1n][1]))),(np.std(groupmushes[group2n][0], ddof=1)/np.sqrt(len(groupmushes[group2n][0])),np.std(groupmushes[group2n][1], ddof=1)/np.sqrt(len(groupmushes[group2n][1])))]
# --> 172         t,p =  sst.ttest_ind(group1diffs, group2diffs)
#     173         df=len(group1diffs)-1
#     174         string=roi+' :'+group1name+'-'+group2name+': t(%.0f)=%.3f, p=%.3f.' % (df,t,p)
#
# /mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/scipy/stats/stats.pyc in ttest_ind(a, b, axis, equal_var)
#    3298         df = n1 + n2 - 2
#    3299         svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / float(df)
# -> 3300         denom = np.sqrt(svar * (1.0 / n1 + 1.0 / n2))
#    3301     else:
#    3302         vn1 = v1 / n1
#
# ZeroDivisionError: float division by zero
