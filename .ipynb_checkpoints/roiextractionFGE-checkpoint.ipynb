# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
import roiextraction_funcs as ref
import seaborn as sns
from mypymvpa.utilities.misc import makeIDs

# %%
#set exp details
rootdir='/mindhive/saxelab2/'
studyname='FGE'
studydir=rootdir+studyname+'/'
roidir='ROI'
taskname='FGE_main'
conditions=['DEV', 'DIP', 'ANN', 'APP', 'DIG', 'EMB', 'FUR', 'GUI', 'JEA', 'TER', 'LON', 'EXC', 'JOY', 'PRO', 'CON', 'GRA', 'HOP', 'IMP', 'NOS', 'SUR', 'PAI']
subjlist=makeIDs('FGE',[1,21])

# %%
#assign colors
allcolors=sns.color_palette("husl", 30)
colors=allcolors[5:16]
colors.extend(allcolors[21:30])
colors.append('brown')

# %%
#specify sets of conditions to combine and compare
valencedict={'pos':{'conds':['EXC', 'JOY','PRO','CON','GRA','HOP','IMP'], 'color':'pink'}, 'neg':{'conds':['DEV','DIP','ANN','APP','DIG','EMB','FUR','GUI','JEA','TER','LON'], 'color':'green'}}
emopaindict={'emo':{'conds':['EXC', 'JOY','PRO','CON','GRA','HOP','IMP', 'SUR', 'DEV','DIP','ANN','APP','DIG','EMB','FUR','GUI','JEA','TER','LON'], 'color':'red'}, 'pain':{'conds':['PAI'], 'color':'brown'}}
comparisons=[valencedict,emopaindict]

# %%
pscfiles,betafiles=ref.findextractedfiles(studydir,roidir,taskname)
# Out:
# /mindhive/saxelab2/FGE/ROI/PSC**FGE_main*

# %%
# %autoreload
ref.analyzepsc(pscfiles,conditions,colors,subjlist, limittimecourse=[1,-2])

# %%
roilist=ref.analyzebetas(betafiles,conditions,colors,subjlist)

# %%
ref.compareconds(studydir,roidir,taskname,roilist,comparisons,subjlist)
# Out:
# {'neg': {'color': 'green', 'conds': ['DEV', 'DIP', 'ANN', 'APP', 'DIG', 'EMB', 'FUR', 'GUI', 'JEA', 'TER', 'LON']}, 'pos': {'color': 'pink', 'conds': ['EXC', 'JOY', 'PRO', 'CON', 'GRA', 'HOP', 'IMP']}}
# DMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(18)=1.102, p=0.285.
# LSTS_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(16)=1.027, p=0.320.
# LTPJ_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(19)=1.211, p=0.241.
# MMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(19)=1.013, p=0.324.
# PC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(19)=-0.276, p=0.785.
# RSTS_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(19)=-0.954, p=0.352.
# RTPJ_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(19)=-0.915, p=0.372.
# VMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(19)=0.991, p=0.334.
# {'emo': {'color': 'red', 'conds': ['EXC', 'JOY', 'PRO', 'CON', 'GRA', 'HOP', 'IMP', 'SUR', 'DEV', 'DIP', 'ANN', 'APP', 'DIG', 'EMB', 'FUR', 'GUI', 'JEA', 'TER', 'LON']}, 'pain': {'color': 'brown', 'conds': ['PAI']}}
# DMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(18)=1.291, p=0.213.
# LSTS_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(16)=1.681, p=0.112.
# LTPJ_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(19)=1.951, p=0.066.
# MMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(19)=1.174, p=0.255.
# PC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(19)=4.082, p=0.001.
# RSTS_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(19)=-0.782, p=0.444.
# RTPJ_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(19)=-0.763, p=0.455.
# VMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(19)=1.306, p=0.207.
