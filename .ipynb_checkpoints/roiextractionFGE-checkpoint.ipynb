# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
import roiextraction_funcs as ref
import seaborn as sns
from mypymvpa.utilities.misc import makeIDs

# %%
#set exp details
rootdir='/mindhive/saxelab2/'
studyname='FGE'
studydir=rootdir+studyname+'/'
roidir='ROI'
taskname='FGE_main'
conditions=['DEV', 'DIP', 'ANN', 'APP', 'DIG', 'EMB', 'FUR', 'GUI', 'JEA', 'TER', 'LON', 'EXC', 'JOY', 'PRO', 'CON', 'GRA', 'HOP', 'IMP', 'NOS', 'SUR', 'PAI']
subjlist=makeIDs('FGE',[1,2,3,4,5])

# %%
#assign colors
allcolors=sns.color_palette("husl", 30)
colors=allcolors[5:16]
colors.extend(allcolors[21:30])
colors.append('brown')

# %%
#specify sets of conditions to combine and compare
valencedict={'pos':{'conds':['EXC', 'JOY','PRO','CON','GRA','HOP','IMP'], 'color':'pink'}, 'neg':{'conds':['DEV','DIP','ANN','APP','DIG','EMB','FUR','GUI','JEA','TER','LON'], 'color':'green'}}
emopaindict={'emo':{'conds':['EXC', 'JOY','PRO','CON','GRA','HOP','IMP', 'SUR', 'DEV','DIP','ANN','APP','DIG','EMB','FUR','GUI','JEA','TER','LON'], 'color':'red'}, 'pain':{'conds':['PAI'], 'color':'brown'}}
comparisons=[valencedict,emopaindict]

# %%
pscfiles,betafiles=ref.findextractedfiles(studydir,roidir,taskname)

# %%
ref.analyzepsc(pscfiles,conditions,colors,subjlist)

# %%
roilist=ref.analyzebetas(betafiles,conditions,colors,subjlist)

# %%
ref.compareconds(studydir,roidir,taskname,roilist,comparisons,subjlist)
# Out:
# DMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(4)=1.474, p=0.215.
# LSTS_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(4)=0.107, p=0.920.
# LTPJ_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(4)=4.263, p=0.013.
# MMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(4)=0.097, p=0.928.
# PC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(4)=1.903, p=0.130.
# RSTS_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(4)=1.980, p=0.119.
# RTPJ_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(4)=6.835, p=0.002.
# VMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(4)=-1.720, p=0.161.
# DMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(4)=3.575, p=0.023.
# LSTS_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(4)=6.749, p=0.003.
# LTPJ_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(4)=5.389, p=0.006.
# MMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(4)=3.857, p=0.018.
# PC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(4)=12.556, p=0.000.
# RSTS_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(4)=3.894, p=0.018.
# RTPJ_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(4)=2.844, p=0.047.
# VMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(4)=3.542, p=0.024.
