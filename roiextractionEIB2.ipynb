# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
import roiextraction_funcs as ref
import seaborn as sns
from mypymvpa.utilities.misc import makeIDs

# %%
#set exp details
rootdir='/mindhive/saxelab2/'
studyname='EIB'
studydir=rootdir+studyname+'/'
roidir='ROI_EIB2'
taskname='EIB_main'
conditions=['nh','nu','rh','ru']
subjlist=makeIDs('EIB',[43,44,45,48,49,50,51,52,53,54,55,56,58,59,60,61])

# %%
#assign colors
colors=sns.color_palette("husl", 8)
colors=[colors[el] for el in [0,1,6,7]]

# %%
#specify sets of conditions to combine and compare
contextdict={'negn':{'conds':['nu'], 'color':'pink'}, 'posn':{'conds':['nh'], 'color':'green'}}
rewarddict={'negr':{'conds':['ru'], 'color':'red'}, 'posr':{'conds':['rh'], 'color':'brown'}}
comparisons=[contextdict,rewarddict]

# %%
pscfiles,betafiles=ref.findextractedfiles(studydir,roidir,taskname)

# %%
ref.analyzepsc(pscfiles,conditions,colors,subjlist)
# Out:
# /mindhive/saxelab/u/askerry/mypythonenv/lib/python2.7/site-packages/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['Arial'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
roilist=ref.analyzebetas(betafiles,conditions,colors,subjlist)

# %%
ref.compareconds(studydir,roidir,taskname,roilist,comparisons,subjlist)
# Out:
# {'posn': {'color': 'green', 'conds': ['nh']}, 'negn': {'color': 'pink', 'conds': ['nu']}}
# VMPFC_Bartra3A_and_Clithero3_meta_mask :posn-negn: t(15)=1.119, p=0.281.
# DMPFC_tomloc_with_art_reg_results_normed_old_con01 :posn-negn: t(15)=-0.982, p=0.341.
# LTPJ_tomloc_with_art_reg_results_normed_old_con01 :posn-negn: t(15)=-0.121, p=0.905.
# MMPFC_tomloc_with_art_reg_results_normed_old_con01 :posn-negn: t(15)=-0.521, p=0.610.
# PC_tomloc_with_art_reg_results_normed_old_con01 :posn-negn: t(15)=-0.344, p=0.735.
# RSTS_tomloc_with_art_reg_results_normed_old_con01 :posn-negn: t(15)=-1.609, p=0.128.
# RTPJ_tomloc_with_art_reg_results_normed_old_con01 :posn-negn: t(15)=-1.357, p=0.195.
# VMPFC_tomloc_with_art_reg_results_normed_old_con01 :posn-negn: t(15)=0.196, p=0.848.
# LSTS_tomloc_with_art_reg_results_normed_old_con01 :posn-negn: t(12)=-0.922, p=0.374.
# {'negr': {'color': 'red', 'conds': ['ru']}, 'posr': {'color': 'brown', 'conds': ['rh']}}
# VMPFC_Bartra3A_and_Clithero3_meta_mask :negr-posr: t(15)=-3.197, p=0.006.
# DMPFC_tomloc_with_art_reg_results_normed_old_con01 :negr-posr: t(15)=0.456, p=0.655.
# LTPJ_tomloc_with_art_reg_results_normed_old_con01 :negr-posr: t(15)=-0.092, p=0.928.
# MMPFC_tomloc_with_art_reg_results_normed_old_con01 :negr-posr: t(15)=-0.873, p=0.396.
# PC_tomloc_with_art_reg_results_normed_old_con01 :negr-posr: t(15)=-0.017, p=0.987.
# RSTS_tomloc_with_art_reg_results_normed_old_con01 :negr-posr: t(15)=-2.151, p=0.048.
# RTPJ_tomloc_with_art_reg_results_normed_old_con01 :negr-posr: t(15)=-0.680, p=0.507.
# VMPFC_tomloc_with_art_reg_results_normed_old_con01 :negr-posr: t(15)=-1.618, p=0.126.
# LSTS_tomloc_with_art_reg_results_normed_old_con01 :negr-posr: t(12)=0.131, p=0.898.

# %% [raw]
# %autoreload
# groupa={'subjects':makeIDs(studyname,[43,44,48,49]),'groupname':'aa'}
# groupb={'subjects':makeIDs(studyname,[53,54,55,56]),'groupname':'bb'}
# ref.comparegroupbetas(studydir,roidir,taskname,roilist,comparisons,[groupa,groupb])
