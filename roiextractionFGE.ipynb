# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
sys.path.append('/mindhive/saxelab/scripts/aesscripts/') #for mypymvpa
import roiextraction_funcs as ref
import seaborn as sns
from mypymvpa.utilities.misc import makeIDs

# %%
#set exp details
rootdir='/mindhive/saxelab2/'
studyname='FGE'
studydir=rootdir+studyname+'/'
roidir='ROI'
taskname='FGE_main'
conditions=['DEV', 'DIP', 'ANN', 'APP', 'DIG', 'EMB', 'FUR', 'GUI', 'JEA', 'TER', 'LON', 'EXC', 'JOY', 'PRO', 'CON', 'GRA', 'HOP', 'IMP', 'NOS', 'SUR', 'PAI']
subjlist=makeIDs('FGE',[1,2,3,4,5,6,7,8,9])

# %%
#assign colors
allcolors=sns.color_palette("husl", 30)
colors=allcolors[5:16]
colors.extend(allcolors[21:30])
colors.append('brown')

# %%
#specify sets of conditions to combine and compare
valencedict={'pos':{'conds':['EXC', 'JOY','PRO','CON','GRA','HOP','IMP'], 'color':'pink'}, 'neg':{'conds':['DEV','DIP','ANN','APP','DIG','EMB','FUR','GUI','JEA','TER','LON'], 'color':'green'}}
emopaindict={'emo':{'conds':['EXC', 'JOY','PRO','CON','GRA','HOP','IMP', 'SUR', 'DEV','DIP','ANN','APP','DIG','EMB','FUR','GUI','JEA','TER','LON'], 'color':'red'}, 'pain':{'conds':['PAI'], 'color':'brown'}}
comparisons=[valencedict,emopaindict]

# %%
pscfiles,betafiles=ref.findextractedfiles(studydir,roidir,taskname)

# %%
ref.analyzepsc(pscfiles,conditions,colors,subjlist)

# %%
roilist=ref.analyzebetas(betafiles,conditions,colors,subjlist)

# %%
ref.compareconds(studydir,roidir,taskname,roilist,comparisons,subjlist)
# Out:
# DMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(8)=2.850, p=0.021.
# LSTS_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(8)=0.411, p=0.692.
# LTPJ_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(8)=5.210, p=0.001.
# MMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(8)=0.192, p=0.853.
# PC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(8)=1.337, p=0.218.
# RSTS_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(8)=2.275, p=0.053.
# RTPJ_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(8)=5.145, p=0.001.
# VMPFC_tomloc_with_art_reg_results_normed_con01 :neg-pos: t(8)=-1.629, p=0.142.
# DMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(8)=3.201, p=0.013.
# LSTS_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(8)=4.448, p=0.002.
# LTPJ_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(8)=6.481, p=0.000.
# MMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(8)=5.635, p=0.000.
# PC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(8)=5.884, p=0.000.
# RSTS_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(8)=6.335, p=0.000.
# RTPJ_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(8)=4.455, p=0.002.
# VMPFC_tomloc_with_art_reg_results_normed_con01 :emo-pain: t(8)=6.066, p=0.000.
